# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
datapath = "sample/test_imaging/SS96_x_7f_f01_1.txt"

# %%
matdat = pd.read_csv(datapath)

# %%
matdat.head()
# Out:
#         Time  Dev1_ai0  Dev1_ai1  Dev1_ai2
# 0      0 sec  0.434398 -0.000832 -0.002453
# 1  0.001 sec  0.254403 -0.002129 -0.002453
# 2  0.002 sec  0.048464 -0.001805 -0.000507
# 3  0.003 sec  0.604014 -0.001156 -0.001480
# 4  0.004 sec  0.427911 -0.000832 -0.002129

# %%
ts = 15000
te = 18000

fig, axs = plt.subplots(3,1,figsize=(30, 10))
axs[0].plot(matdat.Dev1_ai0[ts:te])
axs[1].plot(matdat.Dev1_ai1[ts:te])
axs[2].plot(matdat.Dev1_ai2[ts:te])
